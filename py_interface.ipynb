# %%
import pandas as pd
import wikipediaapi
import openai
import json
import requests

from vars import openai_key, notion_token, notion_database_id

openai.api_key = openai_key

# %%
categorias = pd.read_csv('resources/cat.csv', header=None, index_col=0).index.tolist()

# %%
def get_completion(prompt, model="gpt-3.5-turbo", temperature=0):
    """function to return content from the openai api prompt"""
    messages = [{"role": "user", "content": prompt}]
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=temperature, 
    )
    return response.choices[0].message["content"]

# %%
def import_wiki_page(page_name , language = 'es'):
	"""Importa una página de wikipedia"""
	wiki = wikipediaapi.Wikipedia(language)
	page = wiki.page(page_name)
	exists = page.exists()
	summary = page.summary
	url = page.fullurl
	sections = page.sections
	return page_name, exists, summary, url, sections

# %%
def get_summary(page_name, summary):
	"""Trae summary de una página de wikipedia"""

	prompt = f"""
	Tu tarea es generar un resumen corto de un Artículo de wikipedia sobre {page_name} delimitado en triple comillas simples en no más de 40 palabras
	Conserva el tono informativo e impersonal del artículo.
	Omite información de poca relevancia.
	Clasifíca el artículo en una de las siguientes categorías: {categorias}
	Deriva una lista de como máximo 3 keywords principales del artículo
	El formato de salida SIEMPRE debe ser JSON con los siguientes valores de llave:	resumen, categoria, keywords
	Artículo: '''{summary}'''
	"""

	response = json.loads(get_completion(prompt))

	return response['resumen'], response['categoria'], response['keywords']

# %%
def get_section_summary(page_name, section):
	"""Trae summary de una sección de wikipedia"""
	
	prompt = f"""
	Tu tarea es generar un resumen corto de una sección de un Artículo de wikipedia sobre {page_name} delimitada en triple comillas simples en no más de 40 palabras
	Conserva el tono informativo e impersonal de la sección.
	Omite información de poca relevancia, no incluyas información de otras secciones.
	El formato de salida debe ser texto plano sin comillas.
	Artículo: '''{section}'''
	"""

	response = get_completion(prompt)

	return response

# %%
# Create a new page in Notion
def createPage(databaseID, headers, page_name, summary, url, sections):
    """crea una página en una database de notion"""
    
    resumen, categoria, tags = get_summary(page_name, summary)
    
    createUrl = 'https://api.notion.com/v1/pages'
    newPageData = {
        "parent": { "database_id": databaseID },
        "object": "page",
        "properties": {
            "Título": {
                "title": [
                    {
                        "text": {
                            "content": page_name
                        }
                    }
                ]
            },
            "Tags": {
                    "multi_select":[
                    ]
                },
            "Categoría": {
                "select": {
                    "name": categoria
                }
            },
            "Revisada": {
                    "checkbox": False
                },
            "URL": {
                "url": url
            },
            }
        }
    
    for tag in tags:
        newPageData["properties"]["Tags"]["multi_select"].append({"name": tag})
        
    data = json.dumps(newPageData)

    res_insert = requests.request("POST", createUrl, headers=headers, data=data)
    print(res_insert.status_code)

    newPageID = json.loads(res_insert.content)["id"]
    
    # insert new block of summary in the new page
    newPageData = {
        "children": [
            {
                "object": "block",
                "type": "heading_1",
                "heading_1": {
                    "rich_text": [
                        {
                            "type": "text",
                            "text": {
                                "content": page_name
                            }
                        }
                    ]
                }
            },
            {
                "object": "block",
                "type": "paragraph",
                "paragraph": {
                    "rich_text": [
                        {
                            "type": "text",
                            "text": {
                                "content": resumen
                            }
                        }
                    ]
                }
            }
        ]
    }

    excluded_titles = ['Referencias', 'Véase también', 'Enlaces externos', 'Notas', 'Bibliografía']

    for section in sections:
        if section.title not in excluded_titles:
            newPageData["children"].append({
                    "object": "block",
                    "type": "heading_2",
                    "heading_2": {
                        "rich_text": [
                            {
                                "type": "text",
                                "text": {
                                    "content": section.title
                                }
                            }
                        ]
                    }
                })
            newPageData["children"].append({
                    "object": "block",
                    "type": "paragraph",
                    "paragraph": {
                        "rich_text": [
                            {
                                "type": "text",
                                "text": {
                                    "content": get_section_summary(page_name, section.full_text)
                                }
                            }
                        ]
                    }
                })

    data = json.dumps(newPageData)

    updateURL = f'https://api.notion.com/v1/blocks/{newPageID}/children'
    res_update = requests.request("PATCH", updateURL, headers=headers, data=data)
    print(res_update.status_code)

# %%
headers = {
    "Authorization": "Bearer " + notion_token,
    "Content-Type": "application/json",
    "Notion-Version": "2022-06-28"
}

page_name, exists, summary, url, sections = import_wiki_page('OpenAI')

if exists:
    createPage(notion_database_id, headers, page_name, summary, url, sections)
# Out:
# b'{"object":"page","id":"d78cc55d-1f09-48b4-9500-1adb8c3d404e","created_time":"2023-05-04T19:34:00.000Z","last_edited_time":"2023-05-04T19:34:00.000Z","created_by":{"object":"user","id":"075b3e55-e840-436e-9df8-ec1fc55e920a"},"last_edited_by":{"object":"user","id":"075b3e55-e840-436e-9df8-ec1fc55e920a"},"cover":null,"icon":null,"parent":{"type":"database_id","database_id":"a0911710-5246-4070-8eb3-400075b24127"},"archived":false,"properties":{"Created time":{"id":"NPI%3F","type":"created_time","created_time":"2023-05-04T19:34:00.000Z"},"Revisada":{"id":"Q_NY","type":"checkbox","checkbox":false},"Categor\xc3\xada":{"id":"SPty","type":"select","select":{"id":"b466bee3-7ed0-41f4-bc7e-2a3a8dc5b9f8","name":"Tecnolog\xc3\xada","color":"pink"}},"Tags":{"id":"Zw%3CQ","type":"multi_select","multi_select":[{"id":"8ddc0403-04f9-40d8-a585-96a39135e846","name":"OpenAI","color":"yellow"},{"id":"ac3bb675-c905-422a-a8f7-47661f5e3ca3","name":"inteligencia artificial","color":"red"},{"id":"b0b6621a-f6eb-4fdc-b2a5-81b51a26ca66","name":"Elon Musk","color":"blue"}]},"Created by":{"id":"c%7DVJ","type":"created_by","created_by":{"object":"user","id":"075b3e55-e840-436e-9df8-ec1fc55e920a","name":"wiki-to-notion","avatar_url":null,"type":"bot","bot":{}}},"URL":{"id":"jFNX","type":"url","url":"https://es.wikipedia.org/wiki/OpenAI"},"T\xc3\xadtulo":{"id":"title","type":"title","title":[{"type":"text","text":{"content":"OpenAI","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"OpenAI","href":null}]}},"url":"https://www.notion.so/OpenAI-d78cc55d1f0948b495001adb8c3d404e"}'
# b'{"object":"list","results":[{"object":"block","id":"953becaf-b8cc-4014-ba38-ac753d50b8e5","parent":{"type":"page_id","page_id":"d78cc55d-1f09-48b4-9500-1adb8c3d404e"},"created_time":"2023-05-04T19:34:00.000Z","last_edited_time":"2023-05-04T19:34:00.000Z","created_by":{"object":"user","id":"075b3e55-e840-436e-9df8-ec1fc55e920a"},"last_edited_by":{"object":"user","id":"075b3e55-e840-436e-9df8-ec1fc55e920a"},"has_children":false,"archived":false,"type":"heading_1","heading_1":{"rich_text":[{"type":"text","text":{"content":"OpenAI","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"OpenAI","href":null}],"is_toggleable":false,"color":"default"}},{"object":"block","id":"d20052c5-24c6-4bee-9ef7-8870e76cda00","parent":{"type":"page_id","page_id":"d78cc55d-1f09-48b4-9500-1adb8c3d404e"},"created_time":"2023-05-04T19:34:00.000Z","last_edited_time":"2023-05-04T19:34:00.000Z","created_by":{"object":"user","id":"075b3e55-e840-436e-9df8-ec1fc55e920a"},"last_edited_by":{"object":"user","id":"075b3e55-e840-436e-9df8-ec1fc55e920a"},"has_children":false,"archived":false,"type":"paragraph","paragraph":{"rich_text":[{"type":"text","text":{"content":"OpenAI es una compa\xc3\xb1\xc3\xada sin fines de lucro que busca desarrollar inteligencia artificial amigable para la humanidad y colaborar con otras instituciones e investigadores. Fundada por Elon Musk y Sam Altman, est\xc3\xa1 motivada por preocupaciones sobre el riesgo existencial de la IA general.","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"OpenAI es una compa\xc3\xb1\xc3\xada sin fines de lucro que busca desarrollar inteligencia artificial amigable para la humanidad y colaborar con otras instituciones e investigadores. Fundada por Elon Musk y Sam Altman, est\xc3\xa1 motivada por preocupaciones sobre el riesgo existencial de la IA general.","href":null}],"color":"default"}},{"object":"block","id":"a7392b0a-be3c-48c6-8621-5be189176d6c","parent":{"type":"page_id","page_id":"d78cc55d-1f09-48b4-9500-1adb8c3d404e"},"created_time":"2023-05-04T19:34:00.000Z","last_edited_time":"2023-05-04T19:34:00.000Z","created_by":{"object":"user","id":"075b3e55-e840-436e-9df8-ec1fc55e920a"},"last_edited_by":{"object":"user","id":"075b3e55-e840-436e-9df8-ec1fc55e920a"},"has_children":false,"archived":false,"type":"heading_2","heading_2":{"rich_text":[{"type":"text","text":{"content":"Historia","link":null},"annotations":{"bold":false,"italic":false,"strikethrough":false,"underline":false,"code":false,"color":"default"},"plain_text":"Historia","href":null}],"is_toggleable":false,"color":"default"}},{"object":"block","id":"730c4ff0-5438-41f5-90e7-01b5a89fcaf7","parent":{"type":"page_id","page_id":"d78cc55d-1f09-48b4-9500-1adb8c3d404e"},"created_time":"2023-05-04T19:34:00.000Z","last_edited_time":"2023-05-04T19:34:00.000Z","created_by":{"object":"user","id":"075b3e55-e840-436e-9df8-ec1fc55e920a"},"last_edited_by":{"object":"user","id":"075b3e55-e840-436e-9df8-ec1fc55e920a"},"has_children":false,"archived":false,"type":"paragraph","paragraph":{"rich_text":[{"type":"text","text":{"content":"En octubre de 2015, se anunci\xc3\xb3 la formaci\xc3\xb3n de OpenAI con una inversi\xc3\xb3n de m\xc3\xa1s de mil millones de d\xc3\xb3lares. Desde entonces, han lanzado varias plataformas y tecnolog\xc3\xadas, incluyendo OpenAI Gym, Universe, GPT-3 y GPT-4, as\xc3\xad como una API para estandarizar el desarrollo de tecnolog\xc3\xadas de texto en cualquier idioma. Tambi\xc3\xa9n han desarrollado un bot de IA que gan\xc3\xb3 una demostraci\xc3\xb3n de Dota 2 contra un jugador profesional y han demostrado la capacidad de su IA para crear textos period\xc3\xadsticos. En marzo de 2023, lanzaron una API de ChatGPT y GPT-4. Reid Hoffman renunci\xc3\xb3 a su puesto en el consejo en marzo de 2023.","link":null},"annotations":{"bold":false,"italic":false,"s ...
